# %% [markdown]
# # Step1: Create the Python Script
#
# In the cell below, you will need to complete the Python script and run the cell to generate the file using the magic `%%writefile` command. Your main task is to complete the following methods for the `PersonDetect` class:
# * `load_model`
# * `predict`
# * `draw_outputs`
# * `preprocess_outputs`
# * `preprocess_inputs`
#
# For your reference, here are all the arguments used for the argument parser in the command line:
# * `--model`:  The file path of the pre-trained IR model, which has been pre-processed using the model optimizer. There is automated support built in this argument to support both FP32 and FP16 models targeting different hardware.
# * `--device`: The type of hardware you want to load the model on (CPU, GPU, MYRIAD, HETERO:FPGA,CPU)
# * `--video`: The file path of the input video.
# * `--output_path`: The location where the output stats and video file with inference needs to be stored (results/[device]).
# * `--max_people`: The max number of people in queue before directing a person to another queue.
# * `--threshold`: The probability threshold value for the person detection. Optional arg; default value is 0.60.

# %% [markdown]
# # Next Step
#
# Now that you've run the above cell and created your Python script, you will create your job submission shell script in the next workspace.
#
# **Note**: As a reminder, if you need to make any changes to the Python script, you can come back to this workspace to edit and run the above cell to overwrite the file with your changes.

# %%
# %%writefile person_detect.py

#!/usr/bin/env python3

import argparse
import os
import sys
import time
import subprocess
import logging

import cv2
import numpy as np

from openvino.inference_engine import IENetwork, IECore

try:
    from tqdm import tqdm
except BaseException:
    tqdm = None

logger = logging.getLogger(__name__)


class Queue:
    """Class for dealing with queues."""

    def __init__(self):
        self.queues = []

    def add_queue(self, points):
        self.queues.append(points)

    def get_queues(self, image):
        for q in self.queues:
            x_min, y_min, x_max, y_max = q
            frame = image[y_min:y_max, x_min:x_max]
            yield frame

    def check_coords(self, coords):
        d = {k + 1: 0 for k in range(len(self.queues))}
        for coord in coords:
            for i, q in enumerate(self.queues):
                if coord[0] > q[0] and coord[2] < q[2]:
                    d[i + 1] += 1
        return d


class PersonDetect:
    """Class for the Person Detection Model."""

    def __init__(self, model_name, device, threshold=0.60):
        self.model_weights = model_name + ".bin"
        self.model_structure = model_name + ".xml"
        assert os.path.isfile(self.model_structure) and os.path.isfile(
            self.model_weights
        )
        self.device = device
        self.threshold = threshold
        self._model_size = os.stat(self.model_weights).st_size / 1024.0 ** 2

        self._ie_core = IECore()
        self.model = self._get_model()

        # Get the input layer
        self.input_name = next(iter(self.model.inputs))
        self.input_shape = self.model.inputs[self.input_name].shape
        self.output_name = next(iter(self.model.outputs))
        self.output_shape = self.model.outputs[self.output_name].shape
        self._init_image_w = None
        self._init_image_h = None

    def _get_model(self):
        """Helper function for reading the network."""
        try:
            try:
                model = self._ie_core.read_network(
                    model=self.model_structure, weights=self.model_weights
                )
            except AttributeError:
                model = IENetwork(
                    model=self.model_structure, weights=self.model_weights
                )
        except Exception:
            raise ValueError(
                "Could not Initialise the network. "
                "Have you entered the correct model path?"
            )
        else:
            return model

    def load_model(self):
        """Load the model."""
        # Load the model into the plugin
        self.exec_network = self._ie_core.load_network(
            network=self.model, device_name=self.device
        )

        # Check for supported layers
        #supported_layers = self._ie_core.query_network(
        #    network=self.model, device_name=self.device
        #)
        # Check for any unsupported layers, and let the user know if anything is missing.
        #unsupported_layers = [
        #    l for l in self.model.layers.keys() if l not in supported_layers
        #]
        #if len(unsupported_layers) != 0:
        #    raise RuntimeError(
        #        f"Unsupported layers found: {unsupported_layers}, "
        #        f"Check whether extensions are available to add to IECore."
        #    )

    def predict(self, image, request_id=0):
        if not isinstance(image, np.ndarray):
            raise IOError("Image not parsed correctly.")

        p_image = self.preprocess_input(image)
        self.exec_network.start_async(
            request_id=request_id, inputs={self.input_name: p_image}
        )
        status = self.exec_network.requests[request_id].wait(-1)
        if status == 0:
            result = self.exec_network.requests[request_id].outputs[self.output_name]
            return self.draw_outputs(result, image)

    def draw_outputs(self, inference_blob, image):
        """Draw bounding boxes onto the frame."""
        if not (self._init_image_w and self._init_image_h):
            raise RuntimeError("Initial image width and height cannot be None.")
        label = "Person"
        bbox_color = (0, 255, 0)
        padding_size = (0.05, 0.25)
        text_color = (255, 255, 255)
        text_scale = 1.5
        text_thickness = 1

        coords = []
        for box in inference_blob[0][0]:  # Output shape is 1x1xNx7
            conf = box[2]
            if conf >= self.threshold:
                xmin = int(box[3] * self._init_image_w)
                ymin = int(box[4] * self._init_image_h)
                xmax = int(box[5] * self._init_image_w)
                ymax = int(box[6] * self._init_image_h)
                coords.append((xmin, ymin, xmax, ymax))

                cv2.rectangle(
                    image, (xmin, ymin), (xmax, ymax,), color=bbox_color, thickness=2,
                )

                ((label_width, label_height), _) = cv2.getTextSize(
                    label,
                    cv2.FONT_HERSHEY_PLAIN,
                    fontScale=text_scale,
                    thickness=text_thickness,
                )

                cv2.rectangle(
                    image,
                    (xmin, ymin),
                    (
                        int(xmin + label_width + label_width * padding_size[0]),
                        int(ymin + label_height + label_height * padding_size[1]),
                    ),
                    color=bbox_color,
                    thickness=cv2.FILLED,
                )
                cv2.putText(
                    image,
                    label,
                    org=(
                        xmin,
                        int(ymin + label_height + label_height * padding_size[1]),
                    ),
                    fontFace=cv2.FONT_HERSHEY_PLAIN,
                    fontScale=text_scale,
                    color=text_color,
                    thickness=text_thickness,
                )

        return coords, image

    def preprocess_input(self, image):
        """Helper function for processing frame"""
        p_frame = cv2.resize(image, (self.input_shape[3], self.input_shape[2]))
        # Change data layout from HWC to CHW
        p_frame = p_frame.transpose((2, 0, 1))
        p_frame = p_frame.reshape(1, *p_frame.shape)
        return p_frame


def main(args):

    start_model_load_time = time.time()
    pd = PersonDetect(args.model, args.device, args.threshold)
    pd.load_model()
    total_model_load_time = time.time() - start_model_load_time

    queue = Queue()

    try:
        queue_param = np.load(args.queue_param)
        filename = os.path.split(args.video)[-1].split(".")[0] + ".npy"
        np.save(os.path.join(args.output_path, filename), queue_param)
        for q in queue_param:
            queue.add_queue(q)
    except Exception:
        logger.exception("Error loading queue param file")

    try:
        assert os.path.isfile(args.video)
        cap = cv2.VideoCapture(args.video)
    except (FileNotFoundError, TypeError, AssertionError):
        logger.exception(f"Cannot locate video file: {args.video}")
        raise
    except Exception as err:
        logger.exception(f"Something else went wrong with the video file: {err}")
        raise

    pd._init_image_w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    pd._init_image_h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    video_len = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    if tqdm:
        pbar = tqdm(total=int(video_len - fps + 1))

    out_video = cv2.VideoWriter(
        os.path.join(args.output_path, "output_video.mp4"),
        cv2.VideoWriter_fourcc(*"avc1"),
        fps,
        (pd._init_image_w, pd._init_image_h),
        True,
    )

    counter = 0
    start_inference_time = time.time()

    try:
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            counter += 1

            if tqdm:
                pbar.update(1)

            predict_start_time = time.time()
            coords, image = pd.predict(frame)
            total_inference_time_taken = predict_start_time - time.time()

            num_people = queue.check_coords(coords)

            if tqdm:
                tqdm.write(f"Total People in frame = {len(coords)}")
                tqdm.write(f"Number of people in queue = {num_people}")
            else:
                print(f"Total People in frame = {len(coords)}")
                print(f"Number of people in queue = {num_people}")

            out_text = ""
            y_pixel = 25

            for k, v in num_people.items():
                out_text += f"No. of People in Queue {k} is {v} "
                cv2.putText(
                    image,
                    out_text,
                    (15, y_pixel),
                    cv2.FONT_HERSHEY_COMPLEX,
                    1,
                    (0, 255, 0),
                    2,
                )
                if v >= int(args.max_people):
                    out_text += " Queue full; Please move to next Queue!"
                    cv2.putText(
                        image,
                        out_text,
                        (15, y_pixel),
                        cv2.FONT_HERSHEY_COMPLEX,
                        1,
                        (0, 0, 255),
                        2,
                    )
                out_text = ""
                y_pixel += 40

            # print total_inference_time_taken
            if args.debug:
                cv2.imshow("Frame", image)
            else:
                out_video.write(image)

            key = cv2.waitKey(1) & 0xFF
            # if the `q` key was pressed, break from the loop
            if key == ord("q"):
                break

        total_time = time.time() - start_inference_time
        total_inference_time = round(total_time, 1)
        fps = counter / total_inference_time
        # print fps

        with open(os.path.join(args.output_path, "stats.txt"), "w") as f:
            f.write(str(total_inference_time) + "\n")
            f.write(str(fps) + "\n")
            f.write(str(total_model_load_time) + "\n")
            f.write(str(total_inference_time_taken) + "\n")

        if tqdm:
            pbar.close()
        cap.release()
        cv2.destroyAllWindows()
    except Exception as e:
        logger.exception(f"Could not run Inference: {str(e)}")


if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument(
        "--model",
        required=True,
        help=(
            "The file path of the pre-trained IR model, which has been pre-processed "
            "using the model optimizer. There is automated support built in this "
            "argument to support both FP32 and FP16 models targeting different hardware."
        ),
    )
    parser.add_argument(
        "--device",
        default="CPU",
        help=(
            "The type of hardware you want to load the model on "
            "(CPU, GPU, MYRIAD, HETERO:FPGA,CPU): [default: CPU]"
        ),
    )
    parser.add_argument(
        "--video", default=None, help="The file path of the input video."
    )
    parser.add_argument(
        "--output_path",
        default="/results",
        help=(
            "The location where the output stats and video file with inference needs "
            "to be stored (results/[device])."
        ),
    )
    parser.add_argument(
        "--max_people",
        default=2,
        help=(
            "The max number of people in queue before directing a person to "
            "another queue."
        ),
    )
    parser.add_argument(
        "--threshold",
        default=0.60,
        help=(
            "The probability threshold value for the person detection. "
            "Optional arg; default value is 0.60."
        ),
    )
    parser.add_argument("--queue_param", default=None)
    parser.add_argument(
        "--debug", action="store_true", help="Show output on screen [debugging].",
    )

    args = parser.parse_args()

    main(args)
# Out:
# Overwriting person_detect.py

# %%
# !pip install black flake8
# Out:
# Requirement already satisfied: black in /opt/conda/lib/python3.6/site-packages (19.10b0)
# Requirement already satisfied: flake8 in /opt/conda/lib/python3.6/site-packages (3.8.3)
# Requirement already satisfied: regex in /opt/conda/lib/python3.6/site-packages (from black) (2020.6.8)
# Requirement already satisfied: click>=6.5 in /opt/conda/lib/python3.6/site-packages (from black) (6.7)
# Requirement already satisfied: pathspec<1,>=0.6 in /opt/conda/lib/python3.6/site-packages (from black) (0.8.0)
# Requirement already satisfied: appdirs in /opt/conda/lib/python3.6/site-packages (from black) (1.4.4)
# Requirement already satisfied: toml>=0.9.4 in /opt/conda/lib/python3.6/site-packages (from black) (0.10.1)
# Requirement already satisfied: attrs>=18.1.0 in /opt/conda/lib/python3.6/site-packages (from black) (19.1.0)
# Requirement already satisfied: typed-ast>=1.4.0 in /opt/conda/lib/python3.6/site-packages (from black) (1.4.1)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /opt/conda/lib/python3.6/site-packages (from flake8) (0.6.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.6/site-packages (from flake8) (1.6.1)
# Requirement already satisfied: pycodestyle<2.7.0,>=2.6.0a1 in /opt/conda/lib/python3.6/site-packages (from flake8) (2.6.0)
# Requirement already satisfied: pyflakes<2.3.0,>=2.2.0 in /opt/conda/lib/python3.6/site-packages (from flake8) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->flake8) (3.1.0)

# %%
# !black -l 90 person_detect.py
# !flake8 --max-line-length=90 person_detect.py
# Out:
# reformatted person_detect.py
# All done! ✨ 🍰 ✨
# 1 file reformatted.
# person_detect.py:5:1: F401 'sys' imported but unused
# person_detect.py:7:1: F401 'subprocess' imported but unused

# %%
import py_compile

py_compile.compile("person_detect.py")
# Out:
# '__pycache__/person_detect.cpython-36.pyc'

# %%
# !cat -n person_detect.py
# Out:
#      1	#!/usr/bin/env python3
#      2
#      3	import argparse
#      4	import os
#      5	import sys
#      6	import time
#      7	import subprocess
#      8	import logging
#      9
#     10	import cv2
#     11	import numpy as np
#     12
#     13	from openvino.inference_engine import IENetwork, IECore
#     14
#     15	try:
#     16	    from tqdm import tqdm
#     17	except BaseException:
#     18	    tqdm = None
#     19
#     20	logger = logging.getLogger(__name__)
#     21
#     22
#     23	class Queue:
#     24	    """Class for dealing with queues."""
#     25
#     26	    def __init__(self):
#     27	        self.queues = []
#     28
#     29	    def add_queue(self, points):
#     30	        self.queues.append(points)
#     31
#     32	    def get_queues(self, image):
#     33	        for q in self.queues:
#     34	            x_min, y_min, x_max, y_max = q
#     35	            frame = image[y_min:y_max, x_min:x_max]
#     36	            yield frame
#     37
#     38	    def check_coords(self, coords):
#     39	        d = {k + 1: 0 for k in range(len(self.queues))}
#     40	        for coord in coords:
#     41	            for i, q in enumerate(self.queues):
#     42	                if coord[0] > q[0] and coord[2] < q[2]:
#     43	                    d[i + 1] += 1
#     44	        return d
#     45
#     46
#     47	class PersonDetect:
#     48	    """Class for the Person Detection Model."""
#     49
#     50	    def __init__(self, model_name, device, threshold=0.60):
#     51	        self.model_weights = model_name + ".bin"
#     52	        self.model_structure = model_name + ".xml"
#     53	        assert os.path.isfile(self.model_structure) and os.path.isfile(self.model_weights)
#     54	        self.device = device
#     55	        self.threshold = threshold
#     56	        self._model_size = os.stat(self.model_weights).st_size / 1024.0 ** 2
#     57
#     58	        self._ie_core = IECore()
#     59	        self.model = self._get_model()
#     60
#     61	        # Get the input layer
#     62	        self.input_name = next(iter(self.model.inputs))
#     63	        self.input_shape = self.model.inputs[self.input_name].shape
#     64	        self.output_name = next(iter(self.model.outputs))
#     65	        self.output_shape = self.model.outputs[self.output_name].shape
#     66	        self._init_image_w = None
#     67	        self._init_image_h = None
#     68
#     69	    def _get_model(self):
#     70	        """Helper function for reading the network."""
#     71	        try:
#     72	            try:
#     73	                model = self._ie_core.read_network(
#     74	                    model=self.model_structure, weights=self.model_weights
#     75	                )
#     76	            except AttributeError:
#     77	                model = IENetwork(model=self.model_structure, weights=self.model_weights)
#     78	        except Exception:
#     79	            raise ValueError(
#     80	                "Could not Initialise the network. "
#     81	                "Have you entered the correct model path?"
#     82	            )
#     83	        else:
#     84	            return model
#     85
#     86	    def load_model(self):
#     87	        """Load the model."""
#     88	        # Load the model into the plugin
#     89	        self.exec_network = self._ie_core.load_network(
#     90	            network=self.model, device_name=self.device
#     91	        )
#     92
#     93	        # Check for supported layers
#     94	        # supported_layers = self._ie_core.query_network(
#     95	        #    network=self.model, device_name=self.device
#     96	        # )
#     97	        # Check for any unsupported layers, and let the user know if anything is missing.
#     98	        # unsupported_layers = [
#     99	        #    l for l in self.model.layers.keys() if l not in supported_layers
#    100	        # ]
#    101	        # if len(unsupported_layers) != 0:
#    102	        #    raise RuntimeError(
#    103	        #        f"Unsupported layers found: {unsupported_layers}, "
#    104	        #        f"Check whether extensions are available to add to IECore."
#    105	        #    )
#    106
#    107	    def predict(self, image, request_id=0):
#    108	        if not isinstance(image, np.ndarray):
#    109	            raise IOError("Image not parsed correctly.")
#    110
#    111	        p_image = self.preprocess_input(image)
#    112	        self.exec_network.start_async(
#    113	            request_id=request_id, inputs={self.input_name: p_image}
#    114	        )
#    115	        status = self.exec_network.requests[request_id].wait(-1)
#    116	        if status == 0:
#    117	            result = self.exec_network.requests[request_id].outputs[self.output_name]
#    118	            return self.draw_outputs(result, image)
#    119
#    120	    def draw_outputs(self, inference_blob, image):
#    121	        """Draw bounding boxes onto the frame."""
#    122	        if not (self._init_image_w and self._init_image_h):
#    123	            raise RuntimeError("Initial image width and height cannot be None.")
#    124	        label = "Person"
#    125	        bbox_color = (0, 255, 0)
#    126	        padding_size = (0.05, 0.25)
#    127	        text_color = (255, 255, 255)
#    128	        text_scale = 1.5
#    129	        text_thickness = 1
#    130
#    131	        coords = []
#    132	        for box in inference_blob[0][0]:  # Output shape is 1x1xNx7
#    133	            conf = box[2]
#    134	            if conf >= self.threshold:
#    135	                xmin = int(box[3] * self._init_image_w)
#    136	                ymin = int(box[4] * self._init_image_h)
#    137	                xmax = int(box[5] * self._init_image_w)
#    138	                ymax = int(box[6] * self._init_image_h)
#    139	                coords.append((xmin, ymin, xmax, ymax))
#    140
#    141	                cv2.rectangle(
#    142	                    image, (xmin, ymin), (xmax, ymax,), color=bbox_color, thickness=2,
#    143	                )
#    144
#    145	                ((label_width, label_height), _) = cv2.getTextSize(
#    146	                    label,
#    147	                    cv2.FONT_HERSHEY_PLAIN,
#    148	                    fontScale=text_scale,
#    149	                    thickness=text_thickness,
#    150	                )
#    151
#    152	                cv2.rectangle(
#    153	                    image,
#    154	                    (xmin, ymin),
#    155	                    (
#    156	                        int(xmin + label_width + label_width * padding_size[0]),
#    157	                        int(ymin + label_height + label_height * padding_size[1]),
#    158	                    ),
#    159	                    color=bbox_color,
#    160	                    thickness=cv2.FILLED,
#    161	                )
#    162	                cv2.putText(
#    163	                    image,
#    164	                    label,
#    165	                    org=(
#    166	                        xmin,
#    167	                        int(ymin + label_height + label_height * padding_size[1]),
#    168	                    ),
#    169	                    fontFace=cv2.FONT_HERSHEY_PLAIN,
#    170	                    fontScale=text_scale,
#    171	                    color=text_color,
#    172	                    thickness=text_thickness,
#    173	                )
#    174
#    175	        return coords, image
#    176
#    177	    def preprocess_input(self, image):
#    178	        """Helper function for processing frame"""
#    179	        p_frame = cv2.resize(image, (self.input_shape[3], self.input_shape[2]))
#    180	        # Change data layout from HWC to CHW
#    181	        p_frame = p_frame.transpose((2, 0, 1))
#    182	        p_frame = p_frame.reshape(1, *p_frame.shape)
#    183	        return p_frame
#    184
#    185
#    186	def main(args):
#    187
#    188	    start_model_load_time = time.time()
#    189	    pd = PersonDetect(args.model, args.device, args.threshold)
#    190	    pd.load_model()
#    191	    total_model_load_time = time.time() - start_model_load_time
#    192
#    193	    queue = Queue()
#    194
#    195	    try:
#    196	        queue_param = np.load(args.queue_param)
#    197	        filename = os.path.split(args.video)[-1].split(".")[0] + ".npy"
#    198	        np.save(os.path.join(args.output_path, filename), queue_param)
#    199	        for q in queue_param:
#    200	            queue.add_queue(q)
#    201	    except Exception:
#    202	        logger.exception("Error loading queue param file")
#    203
#    204	    try:
#    205	        assert os.path.isfile(args.video)
#    206	        cap = cv2.VideoCapture(args.video)
#    207	    except (FileNotFoundError, TypeError, AssertionError):
#    208	        logger.exception(f"Cannot locate video file: {args.video}")
#    209	        raise
#    210	    except Exception as err:
#    211	        logger.exception(f"Something else went wrong with the video file: {err}")
#    212	        raise
#    213
#    214	    pd._init_image_w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#    215	    pd._init_image_h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#    216	    video_len = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
#    217	    fps = int(cap.get(cv2.CAP_PROP_FPS))
#    218	    if tqdm:
#    219	        pbar = tqdm(total=int(video_len - fps + 1))
#    220
#    221	    out_video = cv2.VideoWriter(
#    222	        os.path.join(args.output_path, "output_video.mp4"),
#    223	        cv2.VideoWriter_fourcc(*"avc1"),
#    224	        fps,
#    225	        (pd._init_image_w, pd._init_image_h),
#    226	        True,
#    227	    )
#    228
#    229	    counter = 0
#    230	    start_inference_time = time.time()
#    231
#    232	    try:
#    233	        while cap.isOpened():
#    234	            ret, frame = cap.read()
#    235	            if not ret:
#    236	                break
#    237	            counter += 1
#    238
#    239	            if tqdm:
#    240	                pbar.update(1)
#    241
#    242	            predict_start_time = time.time()
#    243	            coords, image = pd.predict(frame)
#    244	            total_inference_time_taken = predict_start_time - time.time()
#    245
#    246	            num_people = queue.check_coords(coords)
#    247
#    248	            if tqdm:
#    249	                tqdm.write(f"Total People in frame = {len(coords)}")
#    250	                tqdm.write(f"Number of people in queue = {num_people}")
#    251	            else:
#    252	                print(f"Total People in frame = {len(coords)}")
#    253	                print(f"Number of people in queue = {num_people}")
#    254
#    255	            out_text = ""
#    256	            y_pixel = 25
#    257
#    258	            for k, v in num_people.items():
#    259	                out_text += f"No. of People in Queue {k} is {v} "
#    260	                cv2.putText(
#    261	                    image,
#    262	                    out_text,
#    263	                    (15, y_pixel),
#    264	                    cv2.FONT_HERSHEY_COMPLEX,
#    265	                    1,
#    266	                    (0, 255, 0),
#    267	                    2,
#    268	                )
#    269	                if v >= int(args.max_people):
#    270	                    out_text += " Queue full; Please move to next Queue!"
#    271	                    cv2.putText(
#    272	                        image,
#    273	                        out_text,
#    274	                        (15, y_pixel),
#    275	                        cv2.FONT_HERSHEY_COMPLEX,
#    276	                        1,
#    277	                        (0, 0, 255),
#    278	                        2,
#    279	                    )
#    280	                out_text = ""
#    281	                y_pixel += 40
#    282
#    283	            # print total_inference_time_taken
#    284	            if args.debug:
#    285	                cv2.imshow("Frame", image)
#    286	            else:
#    287	                out_video.write(image)
#    288
#    289	            key = cv2.waitKey(1) & 0xFF
#    290	            # if the `q` key was pressed, break from the loop
#    291	            if key == ord("q"):
#    292	                break
#    293
#    294	        total_time = time.time() - start_inference_time
#    295	        total_inference_time = round(total_time, 1)
#    296	        fps = counter / total_inference_time
#    297	        # print fps
#    298
#    299	        with open(os.path.join(args.output_path, "stats.txt"), "w") as f:
#    300	            f.write(str(total_inference_time) + "\n")
#    301	            f.write(str(fps) + "\n")
#    302	            f.write(str(total_model_load_time) + "\n")
#    303	            f.write(str(total_inference_time_taken) + "\n")
#    304
#    305	        if tqdm:
#    306	            pbar.close()
#    307	        cap.release()
#    308	        cv2.destroyAllWindows()
#    309	    except Exception as e:
#    310	        logger.exception(f"Could not run Inference: {str(e)}")
#    311
#    312
#    313	if __name__ == "__main__":
#    314	    parser = argparse.ArgumentParser()
#    315	    parser.add_argument(
#    316	        "--model",
#    317	        required=True,
#    318	        help=(
#    319	            "The file path of the pre-trained IR model, which has been pre-processed "
#    320	            "using the model optimizer. There is automated support built in this "
#    321	            "argument to support both FP32 and FP16 models targeting different hardware."
#    322	        ),
#    323	    )
#    324	    parser.add_argument(
#    325	        "--device",
#    326	        default="CPU",
#    327	        help=(
#    328	            "The type of hardware you want to load the model on "
#    329	            "(CPU, GPU, MYRIAD, HETERO:FPGA,CPU): [default: CPU]"
#    330	        ),
#    331	    )
#    332	    parser.add_argument("--video", default=None, help="The file path of the input video.")
#    333	    parser.add_argument(
#    334	        "--output_path",
#    335	        default="/results",
#    336	        help=(
#    337	            "The location where the output stats and video file with inference needs "
#    338	            "to be stored (results/[device])."
#    339	        ),
#    340	    )
#    341	    parser.add_argument(
#    342	        "--max_people",
#    343	        default=2,
#    344	        help=(
#    345	            "The max number of people in queue before directing a person to "
#    346	            "another queue."
#    347	        ),
#    348	    )
#    349	    parser.add_argument(
#    350	        "--threshold",
#    351	        default=0.60,
#    352	        help=(
#    353	            "The probability threshold value for the person detection. "
#    354	            "Optional arg; default value is 0.60."
#    355	        ),
#    356	    )
#    357	    parser.add_argument("--queue_param", default=None)
#    358	    parser.add_argument(
#    359	        "--debug", action="store_true", help="Show output on screen [debugging].",
#    360	    )
#    361
#    362	    args = parser.parse_args()
#    363
#    364	    main(args)
